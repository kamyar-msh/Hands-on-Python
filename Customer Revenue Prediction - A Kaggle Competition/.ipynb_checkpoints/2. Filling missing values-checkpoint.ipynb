# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
train_url = "train1.csv"
train = pd.read_csv(train_url)
test_url = "test1.csv"
test = pd.read_csv(test_url)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # <font color='red'>Numeric and Categorical columns

# %%
numerics = train._get_numeric_data().columns.values.tolist()
categoricals = [col for col in train.columns.values if col not in numerics]

print('numeric columns:')
print(numerics)
print()
print('categorical columns:')
print(categoricals)
# Out:
# numeric columns:
# ['isMobile', 'hits', 'pageviews', 'bounces', 'newVisits', 'transactionRevenue', 'page', 'date', 'visitNumber', 'visitStartTime']
#
# categorical columns:
# ['browser', 'operatingSystem', 'deviceCategory', 'continent', 'subContinent', 'country', 'region', 'metro', 'city', 'networkDomain', 'campaign', 'source', 'medium', 'keyword', 'isTrueDirect', 'referralPath', 'slot', 'gclId', 'adNetworkType', 'isVideoAd', 'adContent', 'channelGrouping', 'sessionId']

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # <font color='red'>Showing all missing values

# %%
d = {}
d_test = {}
types = []
for col in train.columns.values:
    d[col] = len(train[col][train[col].isna() == True])
    if col in numerics:
        types.append('numeric')
    else:
        types.append('categorical')
    #if len(train[col].isna())/train.shape[0] < 0.1:
        #train.drop(col,axis=1, inplace=True)
    if col in  test.columns.values:
        d_test[col] = len(test[col][test[col].isna() == True])
    else:
        d_test[col] = test.shape[0]
df = pd.DataFrame([], columns=['Column name', 'Missing values for train',"Missing values for test"])
df["Column name"] = d.keys()
df["Missing values for train"] = d.values()
df["Missing values for test"] = d_test.values()
df["Type"] = types
df["Train rate"] = df["Missing values for train"]/train.shape[0]
df["Test rate"] = df["Missing values for test"]/test.shape[0]
df.sort_values(by=['Missing values for train'], ascending=False)
# Out:
#            Column name  Missing values for train  Missing values for test  \
# 27           adContent                    891824                   750085
# 8   transactionRevenue                    891256                   803863
# 22                page                    881328                   750073
# 23                slot                    881328                   750073
# 26           isVideoAd                    881328                   750073
# 25       adNetworkType                    881328                   750073
# 24               gclId                    881227                   750025
# 20        isTrueDirect                    629094                   543675
# 21        referralPath                    572048                   568740
# 19             keyword                    502486                   390615
# 6              bounces                    452378                   383152
# 7            newVisits                    200320                   200018
# 5            pageviews                       100                      138
# 0              browser                         0                        0
# 29                date                         0                        0
# 30           sessionId                         0                        0
# 31         visitNumber                         0                        0
# 28     channelGrouping                         0                        0
# 16            campaign                         0                        0
# 18              medium                         0                        0
# 17              source                         0                        0
# 1      operatingSystem                         0                        0
# 15       networkDomain                         0                        0
# 14                city                         0                        0
# 13               metro                         0                        0
# 12              region                         0                        0
# 11             country                         0                        0
# 10        subContinent                         0                        0
# 9            continent                         0                        0
# 4                 hits                         0                        0
# 3       deviceCategory                         0                        0
# 2             isMobile                         0                        0
# 32      visitStartTime                         0                        0
#
#            Type  Train rate  Test rate
# 27  categorical    0.987892   0.933101
# 8       numeric    0.987262   1.000000
# 22      numeric    0.976265   0.933086
# 23  categorical    0.976265   0.933086
# 26  categorical    0.976265   0.933086
# 25  categorical    0.976265   0.933086
# 24  categorical    0.976153   0.933026
# 20  categorical    0.696860   0.676328
# 21  categorical    0.633669   0.707509
# 19  categorical    0.556614   0.485922
# 6       numeric    0.501108   0.476638
# 7       numeric    0.221899   0.248821
# 5       numeric    0.000111   0.000172
# 0   categorical    0.000000   0.000000
# 29      numeric    0.000000   0.000000
# 30  categorical    0.000000   0.000000
# 31      numeric    0.000000   0.000000
# 28  categorical    0.000000   0.000000
# 16  categorical    0.000000   0.000000
# 18  categorical    0.000000   0.000000
# 17  categorical    0.000000   0.000000
# 1   categorical    0.000000   0.000000
# 15  categorical    0.000000   0.000000
# 14  categorical    0.000000   0.000000
# 13  categorical    0.000000   0.000000
# 12  categorical    0.000000   0.000000
# 11  categorical    0.000000   0.000000
# 10  categorical    0.000000   0.000000
# 9   categorical    0.000000   0.000000
# 4       numeric    0.000000   0.000000
# 3   categorical    0.000000   0.000000
# 2       numeric    0.000000   0.000000
# 32      numeric    0.000000   0.000000

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color='red'>Overview of columns

# %%
for col in train.columns.values:
    print(col,":")
    print(train[col].describe())
    print()
# Out:
# browser :
# count     902755
# unique        54
# top       Chrome
# freq      619699
# Name: browser, dtype: object
#
# operatingSystem :
# count      902755
# unique         20
# top       Windows
# freq       349711
# Name: operatingSystem, dtype: object
#
# isMobile :
# count     902755
# unique         2
# top        False
# freq      663866
# Name: isMobile, dtype: object
#
# deviceCategory :
# count      902755
# unique          3
# top       desktop
# freq       663814
# Name: deviceCategory, dtype: object
#
# hits :
# count    902755.000000
# mean          4.591720
# std           9.634079
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max         500.000000
# Name: hits, dtype: float64
#
# pageviews :
# count    902655.000000
# mean          3.846323
# std           7.020076
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           4.000000
# max         469.000000
# Name: pageviews, dtype: float64
#
# bounces :
# count    450377.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: bounces, dtype: float64
#
# newVisits :
# count    702435.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: newVisits, dtype: float64
#
# transactionRevenue :
# count    1.149900e+04
# mean     1.337412e+08
# std      4.485768e+08
# min      1.000000e+04
# 25%      2.486500e+07
# 50%      4.934000e+07
# 75%      1.074550e+08
# max      2.312950e+10
# Name: transactionRevenue, dtype: float64
#
# continent :
# count       902755
# unique           6
# top       Americas
# freq        449996
# Name: continent, dtype: object
#
# subContinent :
# count               902755
# unique                  23
# top       Northern America
# freq                390295
# Name: subContinent, dtype: object
#
# country :
# count            902755
# unique              222
# top       United States
# freq             364401
# Name: country, dtype: object
#
# region :
# count                            902755
# unique                              376
# top       not available in demo dataset
# freq                             507780
# Name: region, dtype: object
#
# metro :
# count                            902755
# unique                               94
# top       not available in demo dataset
# freq                             507780
# Name: metro, dtype: object
#
# city :
# count                            902755
# unique                              649
# top       not available in demo dataset
# freq                             507780
# Name: city, dtype: object
#
# networkDomain :
# count        902755
# unique        28064
# top       (not set)
# freq         244647
# Name: networkDomain, dtype: object
#
# campaign :
# count        902755
# unique           10
# top       (not set)
# freq         864514
# Name: campaign, dtype: object
#
# source :
# count     902755
# unique       380
# top       google
# freq      400340
# Name: source, dtype: object
#
# medium :
# count      902755
# unique          7
# top       organic
# freq       381137
# Name: medium, dtype: object
#
# keyword :
# count             400269
# unique              3658
# top       (not provided)
# freq              365950
# Name: keyword, dtype: object
#
# isTrueDirect :
# count     273661
# unique         1
# top         True
# freq      273661
# Name: isTrueDirect, dtype: object
#
# referralPath :
# count     330707
# unique      1475
# top            /
# freq       75435
# Name: referralPath, dtype: object
#
# page :
# count    21427.000000
# mean         1.008121
# std          0.173717
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         14.000000
# Name: page, dtype: float64
#
# slot :
# count     21427
# unique        2
# top         Top
# freq      20924
# Name: slot, dtype: object
#
# gclId :
# count                                                 21528
# unique                                                17774
# top       Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3Zd...
# freq                                                     70
# Name: gclId, dtype: object
#
# adNetworkType :
# count             21427
# unique                2
# top       Google Search
# freq              21420
# Name: adNetworkType, dtype: object
#
# isVideoAd :
# count     21427
# unique        1
# top       False
# freq      21427
# Name: isVideoAd, dtype: object
#
# adContent :
# count                             10931
# unique                               44
# top       Google Merchandise Collection
# freq                               5112
# Name: adContent, dtype: object
#
# channelGrouping :
# count             902755
# unique                 8
# top       Organic Search
# freq              381137
# Name: channelGrouping, dtype: object
#
# date :
# count    9.027550e+05
# mean     2.016588e+07
# std      4.697683e+03
# min      2.016080e+07
# 25%      2.016103e+07
# 50%      2.017011e+07
# 75%      2.017042e+07
# max      2.017080e+07
# Name: date, dtype: float64
#
# sessionId :
# count                            902755
# unique                           902755
# top       903746447129119211_1473751093
# freq                                  1
# Name: sessionId, dtype: object
#
# visitNumber :
# count    902755.000000
# mean          2.265059
# std           9.287168
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max         395.000000
# Name: visitNumber, dtype: float64
#
# visitStartTime :
# count    9.027550e+05
# mean     1.485006e+09
# std      9.021361e+06
# min      1.470035e+09
# 25%      1.477562e+09
# 50%      1.483945e+09
# 75%      1.492755e+09
# max      1.501657e+09
# Name: visitStartTime, dtype: float64

# %% [markdown]
# ---------------------------

# %% [markdown]
# # <font color='red'>Variables with only one value and NaN

# %%
for col in train.columns.values:
    if len(train[col].unique()) == 2 and train[col].isnull().values.any():
        print(col)
        print(train[col].unique())
# Out:
# bounces
# [  1.  nan]
# newVisits
# [  1.  nan]
# isTrueDirect
# [nan True]
# isVideoAd
# [nan False]

# %% [markdown]
# It seems that for numeric columns *bounces* and *newVisits*, the missing values indicate 0, and for boolean columns *isTrueDirect* and *isVideoAd* the missing values indcate __False__ and __True__ respectively. Therefore instead of removing them, we impute their missing values:

# %%
train["bounces"].fillna(0,inplace=True)
train["newVisits"].fillna(0,inplace=True)
train["isTrueDirect"].fillna(False,inplace=True)
train["isVideoAd"].fillna(True,inplace=True)

test["bounces"].fillna(0,inplace=True)
test["newVisits"].fillna(0,inplace=True)
test["isTrueDirect"].fillna(False,inplace=True)
test["isVideoAd"].fillna(True,inplace=True)

# %% [markdown]
# Now it's better to convert boolean columns to numerics, 0 represents __False__ and 1 represents __True__:

# %%
train["isTrueDirect"][train["isTrueDirect"] == False] = 0.0
train["isTrueDirect"][train["isTrueDirect"] == True] = 1.0

train["isVideoAd"][train["isVideoAd"] == False] = 0.0
train["isVideoAd"][train["isVideoAd"] == True] = 1.0

test["isTrueDirect"][test["isTrueDirect"] == False] = 0.0
test["isTrueDirect"][test["isTrueDirect"] == True] = 1.0

test["isVideoAd"][test["isVideoAd"] == False] = 0.0
test["isVideoAd"][test["isVideoAd"] == True] = 1.0

# %% [markdown]
# It's worth to check if there are other boolean columns:

# %%
for col in train.columns.values:
    if False in train[col].unique() and len(train[col].unique()) == 2 :
        print(col)
        print(train[col].unique())
        print()
# Out:
# isMobile
# [False  True]
#
# bounces
# [ 1.  0.]
#
# newVisits
# [ 1.  0.]
#
# isTrueDirect
# [False  True]
#
# isVideoAd
# [ True False]

# %% [markdown]
# Now we convert *isMobile* to numeric:

# %%
train["isMobile"][train["isMobile"] == False] = 0.0
train["isMobile"][train["isMobile"] == True] = 1.0

test["isMobile"][test["isMobile"] == False] = 0.0
test["isMobile"][test["isMobile"] == True] = 1.0

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# # <font color='red'>A brief look into the target

# %% [markdown]
# *transactionRevenue* is the target and missing values probably indicate 0 revenue

# %%
print("Number of non-NaN values: ", len(train["transactionRevenue"][train["transactionRevenue"].isna() == False]))
# Out:
# Number of non-NaN values:  11499

# %% [markdown]
# ### <font color='blue'>Converting target missings to 0</font>

# %%
train["transactionRevenue"].fillna(0,inplace=True)

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# # <font color='red'>Imputing missing values

# %% [markdown]
# Let's see how many columns still contain missing values:

# %%
d = {}
d_test = {}
types = []
for col in train.columns.values:
    d[col] = len(train[col][train[col].isna() == True])
    if col in numerics:
        types.append('numeric')
    else:
        types.append('categorical')
    #if len(train[col].isna())/train.shape[0] < 0.1:
        #train.drop(col,axis=1, inplace=True)
    if col in  test.columns.values:
        d_test[col] = len(test[col][test[col].isna() == True])
    else:
        d_test[col] = test.shape[0]
df = pd.DataFrame([], columns=['Column name', 'Missing values for train',"Missing values for test"])
df["Column name"] = d.keys()
df["Missing values for train"] = d.values()
df["Missing values for test"] = d_test.values()
df["Type"] = types
df["Train rate"] = df["Missing values for train"]/train.shape[0]
df["Test rate"] = df["Missing values for test"]/test.shape[0]
df[df['Missing values for train'] > 0].sort_values(by=['Missing values for train'], ascending=False)
# Out:
#       Column name  Missing values for train  Missing values for test  \
# 27      adContent                    891824                   750085
# 22           page                    881328                   750073
# 23           slot                    881328                   750073
# 25  adNetworkType                    881328                   750073
# 24          gclId                    881227                   750025
# 21   referralPath                    572048                   568740
# 19        keyword                    502486                   390615
# 5       pageviews                       100                      138
#
#            Type  Train rate  Test rate
# 27  categorical    0.987892   0.933101
# 22      numeric    0.976265   0.933086
# 23  categorical    0.976265   0.933086
# 25  categorical    0.976265   0.933086
# 24  categorical    0.976153   0.933026
# 21  categorical    0.633669   0.707509
# 19  categorical    0.556614   0.485922
# 5       numeric    0.000111   0.000172

# %%
for col in df["Column name"][df['Missing values for train'] > 0]:
    print(col)
    print(train[col].describe())
    print()
# Out:
# pageviews
# count    902655.000000
# mean          3.846323
# std           7.020076
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           4.000000
# max         469.000000
# Name: pageviews, dtype: float64
#
# keyword
# count             400269
# unique              3658
# top       (not provided)
# freq              365950
# Name: keyword, dtype: object
#
# referralPath
# count     330707
# unique      1475
# top            /
# freq       75435
# Name: referralPath, dtype: object
#
# page
# count    21427.000000
# mean         1.008121
# std          0.173717
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         14.000000
# Name: page, dtype: float64
#
# slot
# count     21427
# unique        2
# top         Top
# freq      20924
# Name: slot, dtype: object
#
# gclId
# count                                                 21528
# unique                                                17774
# top       Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3Zd...
# freq                                                     70
# Name: gclId, dtype: object
#
# adNetworkType
# count             21427
# unique                2
# top       Google Search
# freq              21420
# Name: adNetworkType, dtype: object
#
# adContent
# count                             10931
# unique                               44
# top       Google Merchandise Collection
# freq                               5112
# Name: adContent, dtype: object

# %% [markdown]
# For those categorical variables which have less than 70% missing values, missings are replaced with mode (categoricals) and median (numerics):

# %%
train["pageviews"].fillna(train["pageviews"].median(),inplace=True)
train["keyword"].fillna(train["keyword"].mode()[0],inplace=True)
train["referralPath"].fillna(train["referralPath"].mode()[0],inplace=True)

test["pageviews"].fillna(test["pageviews"].median(),inplace=True)
test["keyword"].fillna(test["keyword"].mode()[0],inplace=True)
test["referralPath"].fillna(test["referralPath"].mode()[0],inplace=True)

# %% [markdown]
# The other variables contain more than 97% missing values, so they can be removed:

# %%
for col in train.columns.values:
    if len(train[col][train[col].isna()==True])/train.shape[0] > 0.90:
        print(col)
        train.drop(col,axis=1, inplace=True)
        test.drop(col,axis=1, inplace=True)
        if col in categoricals:
            categoricals.remove(col)
        if col in numerics:
            numerics.remove(col)
# Out:
# page
# slot
# gclId
# adNetworkType
# adContent

# %% [markdown]
# Checking if there are still missing values in the dataset:

# %%
train.isnull().values.any()
# Out:
# False

# %% [markdown]
# # <font color='red'> Writing the final dataframe to .csv

# %%
train.to_csv('train2.csv', index=False, encoding='utf-8')
test.to_csv('test2.csv', index=False, encoding='utf-8')
